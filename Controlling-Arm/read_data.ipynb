# %%
#!/usr/bin/env python3
#coding=utf-8
import os
import time
from pymycobot.mycobot import MyCobot

# %%
mc = MyCobot('/dev/ttyUSB0', 1000000)
# Out:
# Note: This class is no longer maintained since v3.6.0, please refer to the project documentation: https://github.com/elephantrobotics/pymycobot/blob/main/README.md

# %%
angles = mc.get_angles()
print("read angles:", angles)
# Out:
# read angles: [0.79, -0.61, 0.26, -0.79, 0.61, -45.61]

# %%
coords = mc.get_coords()
print("read coords:", coords)
# Out:
# read coords: [52.7, -63.3, 409.8, -91.63, -45.59, -87.42]

# %%
encoders = mc.get_encoders()
print("encoders:", encoders)

# %%
radians = mc.get_radians()
print("read radians:", radians)

# %%
gripper = mc.get_gripper_value()
print("gripper:", gripper)
