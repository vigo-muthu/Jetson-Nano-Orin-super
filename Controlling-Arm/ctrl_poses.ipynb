# %%
import os
import ipywidgets.widgets as widgets
from IPython.display import display
import time
import threading
from pymycobot.mycobot import MyCobot
from pymycobot.genre import Angle

# %%
mc = MyCobot('/dev/ttyUSB0', 1000000)
g_speed = 50

# %%
def reset_joints():
    mc.send_angles([0, 0, 0, 0, 0, -45], 50)
    mc.set_gripper_value(100, 50)

reset_joints()

# %%
def ctrl_poses(id):
    if id == 1:
        angles = [2.72, 49.39, -128.67, -76.72, 3.16, -44.2]
        mc.send_angles(angles, g_speed)
    elif id == 2:
        angles = [84.63, -85.78, -0.61, -93.07, 86.22, -44.2]
        mc.send_angles(angles, g_speed)
    elif id == 3:
        angles = [-93.69, -85.78, -0.61, -85.78, -86.13, -44.29]
        mc.send_angles(angles, g_speed)
    elif id == 4:
        angles = [-0.26, -40.42, -50.62, -92.98, -0.79, -44.2]
        mc.send_angles(angles, g_speed)
    elif id == 5:
        angles = [-0.35, 63.1, -143.26, -73.82, 10.81, -44.73]
        mc.send_angles(angles, g_speed)
    elif id == 6:
        angles = [0, -15, -135, 123, -25, -45]
        mc.send_angles(angles, g_speed)
    elif id == 7:
        angles = [-0.43, -0.96, -3.69, -88.76, 10.81, -47.63]
        mc.send_angles(angles, g_speed)
    elif id == 8:
        angles = [-97.55, 59.85, -130.25, -70.22, -88.5, -42.01]
        mc.send_angles(angles, g_speed)
    elif id == 9:
        angles = [-0.43, 89, -93.95, -36.73, -10.45, -46.23]
        mc.send_angles(angles, g_speed)
    elif id == 10:
        angles = [108.19, -92.1, 125.85, -79.71, -9.74, -43.95]
        mc.send_angles(angles, g_speed)

# %%
button_reset = widgets.Button(     
    description='Reset',        
    button_style='info', # 'success', 'info', 'warning', 'danger' or ''     
    tooltip='Description',
    icon='uncheck' )

button_poses_1 = widgets.Button(     
    description='Poses_1',        
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''     
    tooltip='Description',
    icon='uncheck' )

button_poses_2 = widgets.Button(     
    description='Poses_2',        
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''     
    tooltip='Description',
    icon='uncheck' )

button_poses_3 = widgets.Button(     
    description='Poses_3',        
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''     
    tooltip='Description',
    icon='uncheck' )

button_poses_4 = widgets.Button(     
    description='Poses_4',        
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''     
    tooltip='Description',
    icon='uncheck' )

button_poses_5 = widgets.Button(     
    description='Poses_5',        
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''     
    tooltip='Description',
    icon='uncheck' )

button_poses_6 = widgets.Button(     
    description='Poses_6',        
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''     
    tooltip='Description',
    icon='uncheck' )

button_poses_7 = widgets.Button(     
    description='Poses_7',        
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''     
    tooltip='Description',
    icon='uncheck' )

button_poses_8 = widgets.Button(     
    description='Poses_8',        
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''     
    tooltip='Description',
    icon='uncheck' )

button_poses_9 = widgets.Button(     
    description='Poses_9',        
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''     
    tooltip='Description',
    icon='uncheck' )

button_poses_10 = widgets.Button(     
    description='Poses_10',        
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''     
    tooltip='Description',
    icon='uncheck' )

def on_button_clicked(b):
    with output:
        print("Button clicked:", b.description)
    if b.description == 'Reset':
        reset_joints()
    elif b.description == 'Poses_1':
        ctrl_poses(1)
    elif b.description == 'Poses_2':
        ctrl_poses(2)
    elif b.description == 'Poses_3':
        ctrl_poses(3)
    elif b.description == 'Poses_4':
        ctrl_poses(4)
    elif b.description == 'Poses_5':
        ctrl_poses(5)
    elif b.description == 'Poses_6':
        ctrl_poses(6)
    elif b.description == 'Poses_7':
        ctrl_poses(7)
    elif b.description == 'Poses_8':
        ctrl_poses(8)
    elif b.description == 'Poses_9':
        ctrl_poses(9)
    elif b.description == 'Poses_10':
        ctrl_poses(10)


button_reset.on_click(on_button_clicked)    
button_poses_1.on_click(on_button_clicked)    
button_poses_2.on_click(on_button_clicked)    
button_poses_3.on_click(on_button_clicked)    
button_poses_4.on_click(on_button_clicked)    
button_poses_5.on_click(on_button_clicked)    
button_poses_6.on_click(on_button_clicked)    
button_poses_7.on_click(on_button_clicked)    
button_poses_8.on_click(on_button_clicked)    
button_poses_9.on_click(on_button_clicked)    
button_poses_10.on_click(on_button_clicked)

# %%
output = widgets.Output()
group_1 = widgets.HBox([button_poses_1, button_poses_2, button_poses_3, button_poses_4, button_poses_5])
group_2 = widgets.HBox([button_poses_6, button_poses_7, button_poses_8, button_poses_9, button_poses_10])
box_display = widgets.VBox([button_reset, group_1, group_2, output])

display(box_display)
